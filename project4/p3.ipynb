# %%
inputA = []
A = []
print("Input:")
inputA = input()
inputA = inputA.split()
for i in inputA:
  A.append(int(i))

abssum = []
for a in A:
  for b in A:
    abssum.append(abs(a+b))
    
print("\nOutput:")
print(min(abssum))
# Out:
# Input:
# -8 4 5 -10 3
#
# Output:
# 3
